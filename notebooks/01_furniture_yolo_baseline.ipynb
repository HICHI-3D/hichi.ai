# %% [markdown]
# # 가구 검출 베이스라인 (YOLOv8)
#
# 사전학습된 YOLOv8n에 가구 사진을 넣어 결과를 살펴본다.
# 이후 자체 가구 데이터셋으로 fine-tune 진행.

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
# results = model('data/sample/sofa.jpg')
# results[0].show()
